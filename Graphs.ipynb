# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pickle

# %%
infos = pickle.load(open('test_run.pkl', 'rb'))
obs = ["pelvis rotation", "pelvis x", "pelvis y", "velocity pelvis rotation", "velocity pelvis x", "velocity pelvis y", "hip_r rotation", "knee_r rotation", "ankle_r rotation", "hip_l rotation", "knee_l rotation", "ankle_l rotation", "hip_r velocity", "knee_r velocity", "ankle_r velocity", "hip_l velocity", "knee_l velocity", "ankle_l velocity", "center of mass x", "center of mass y", "center of mass x velocity", "center of mass y velocity", "head x", "head y", "pelvis x", "pelvis y", "torso x", "torso y", "toes_l_x", "toes_l_y", "toes_r_x", "toes_r_y", "talus_l_x", "talus_l_y", "talus_r_x", "talus_r_y", "psoas l", "psoas r", "obstacle x", "y position of obstacle", "radius of obstacle"]

# %%
for i in range(20):
    plt.figure(i)
    plt.plot(map(lambda x: x[i], infos['ob']))
    plt.xlabel(str(i) + ":" + obs[i])

# %%
for i in range(20, 41):
    plt.figure(i)
    plt.plot(map(lambda x: x[i], infos['ob']))
    plt.xlabel(str(i) + ":" + obs[i])

# %%
import numpy as np

# %%
np.clip?

# %%
np.clip(np.array([1,2,3,4]), 2, 2.5)
# Out:
# array([ 2. ,  2. ,  2.5,  2.5])

# %%
infos.keys()
# Out:
# ['action', 'tot_rew', 'reward', 'ob']

# %%
infos['action'][0]
# Out:
# array([-0.07086635, -0.32759428,  0.16303918, -0.12111952, -0.32916275,
#        -0.69108802,  0.40436199, -0.00762507,  0.8436029 ,  1.33968663,
#         0.12493628,  1.2002995 , -0.85898352, -0.36413604,  0.00788561,
#        -0.17673862, -0.87283558,  1.03303933], dtype=float32)
